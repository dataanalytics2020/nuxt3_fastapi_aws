# %%
from selenium import webdriver
import time
import pandas as pd
import re
from selenium.webdriver.common.by import By
#from datetime import datetime, date, timedelta
from selenium.webdriver.chrome.options import Options
import requests
import json

from webdriver_manager.chrome import ChromeDriverManager
import mysql
import mysql.connector
import os

import datetime
import unicodedata

from dotenv import load_dotenv
load_dotenv(".env")
# Out:
# True

# %%
import mysql.connector
def get_cursor():
    # MySQLに接続
    conn = mysql.connector.connect(
        host=os.environ.get("AWS_SLOMAP_RDS_HOST"),
        user=os.environ.get("AWS_SLOMAP_RDS_USER"),
        password=os.environ.get("AWS_SLOMAP_RDS_PASSWORD"),
        database=os.environ.get("AWS_SLOMAP_RDS_DATABASE"),
    )
    return conn

conn = get_cursor()
# カーソルを取得
cursor = conn.cursor()

# %% [markdown]
# ### MYSQLのバージョンを確認する

# %%
conn = get_cursor()
# カーソルを取得
cursor = conn.cursor()
sql = f"""select version();
        """
print(sql)
cursor.execute(sql)
myresult = cursor.fetchall()
 
print(myresult)
# Out:
# select version();
#
# [('8.0.35',)]

# %% [markdown]
# ### テーブルの数を数える

# %%
cursor.execute("show databases;")
myresult = cursor.fetchall()
 
for x in myresult:
  print(x[0])
# Out:
# information_schema
# mysql
# performance_schema
# public
# sys

# %%
cursor.execute("show tables;")
myresult = cursor.fetchall()
 
for x in myresult:
  print(x[0])
# Out:
# halldata

# %% [markdown]
# ### それぞれのテーブルの確認

# %%
for table_name in myresult:
        print(table_name[0])
        sql = f"""
SELECT *
FROM {table_name[0]} 
limit 10"""
        print(sql)
        cursor.execute(sql)
        #cols = [col[0] for col in cursor.description]
        cols = cursor.column_names
        convart_table_df = pd.DataFrame(cursor.fetchall(),columns = cols)
        display(convart_table_df.head())
# Out:
# halldata
#
# SELECT *
# FROM halldata
# limit 10
#       id     hall_name prefecture_name
# 0  10003        アリーナ羽伏             東京都  \
# 1  10004    パーラーみやけ坪田店             東京都
# 2  10008      アイランド秋葉原             東京都
# 3  10009  ビッグアップル.秋葉原店             東京都
# 4  10013      みとや神田西口店             東京都
#
#                                             hall_url
# 0  https://hall-navi.com/hole_view?hid=1000400000...  \
# 1  https://hall-navi.com/hole_view?hid=1001101000...
# 2  https://hall-navi.com/hole_view?hid=1010021000...
# 3  https://hall-navi.com/hole_view?hid=1010021000...
# 4  https://hall-navi.com/hole_view?hid=1010047000...
#
#                                    dmm_url
# 0  https://p-town.dmm.com/shops/tokyo/1027  \
# 1  https://p-town.dmm.com/shops/tokyo/1028
# 2     https://p-town.dmm.com/shops/tokyo/9
# 3     https://p-town.dmm.com/shops/tokyo/7
# 4    https://p-town.dmm.com/shops/tokyo/20
#
#                                           pworld_url
# 0                                                     \
# 1
# 2          http://www.p-world.co.jp/tokyo/island.htm
# 3       http://www.p-world.co.jp/tokyo/big-apple.htm
# 4  http://www.p-world.co.jp/tokyo/mitoya-kandanis...
#
#                              line_url                       twitter_url
# 0                                                                        \
# 1
# 2              https://lin.ee/n24S9oy  https://twitter.com/akiba_island
# 3  https://line.me/R/ti/p/%40ozs2880u      https://twitter.com/ba_akiba
# 4
#
#   nearest_station           address  ...  machine_move  dedama_share
# 0                     東京都新島村字南桧山4-1  ...                              \
# 1                   東京都三宅島三宅村坪田2987  ...
# 2             秋葉原   東京都千代田区外神田4-3-3  ...            可能            可能
# 3             秋葉原  東京都千代田区外神田1-16-1  ...            可能            可能
# 4              神田   東京都千代田区内神田2-9-8  ...
#
#   car_parking mobile_charging dedama_info access_info longitude latitude
# 0                                                       139.257  34.3772  \
# 1                                                       139.549  34.0616
# 2          無し              可能      PAPIMO          無し   139.772  35.7007
# 3          無し              可能      PAPIMO          無し   139.771  35.6972
# 4                                                       139.768  35.6912
#
#     anaslo_name  bicycle_parking
# 0
# 1
# 2     アイランド秋葉原店               無し
# 3  ビッグアップル．秋葉原店               無し
# 4
#
# [5 rows x 23 columns]

# %% [markdown]
# ### maptableの東京都の店舗のレコード数を数える

# %%
sql = f"""
        SELECT COUNT(*)
        FROM maptable
        Where 都道府県 = '東京都'

        """
print(sql)
cursor.execute(sql)
myresult = cursor.fetchall()
 
print(myresult)
# Out:
# 2023-10-15 00:22:14.353864
# 2023-10-15 00:22:15,156| ERROR   | Could not open connection to gateway
# ---------------------------------------------------------------------------
# BaseSSHTunnelForwarderError               Traceback (most recent call last)
# c:\Users\tsc95\Desktop\flask_website\test\sql_table_join_practice.ipynb セル 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> cursor, cnx, server = get_driver()
#       <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> sql = f"""
#       <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a>         SELECT COUNT(*)
#       <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a>         FROM maptable
#       <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a>         Where 都道府県 = '東京都'
#       <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a>
#       <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a>         """
#       <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a> print(sql)
#
# c:\Users\tsc95\Desktop\flask_website\test\sql_table_join_practice.ipynb セル 10 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a> yesterday:str = (today + datetime.timedelta(days=-2)).strftime('%Y-%m-%d')
#      <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X12sZmlsZQ%3D%3D?line=19'>20</a> #### Create dataframe from resultant table ####
# ---> <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X12sZmlsZQ%3D%3D?line=21'>22</a> server.start()
#      <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X12sZmlsZQ%3D%3D?line=23'>24</a> print(f"local bind port: {server.local_bind_port}")
#      <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X12sZmlsZQ%3D%3D?line=24'>25</a> # データベース接続
#
# File c:\Users\tsc95\Desktop\flask_website\.venv\lib\site-packages\sshtunnel.py:1331, in SSHTunnelForwarder.start(self)
#    1329 self._create_tunnels()
#    1330 if not self.is_active:
# -> 1331     self._raise(BaseSSHTunnelForwarderError,
#    1332                 reason='Could not establish session to SSH gateway')
#    1333 for _srv in self._server_list:
#    1334     thread = threading.Thread(
#    1335         target=self._serve_forever_wrapper,
#    1336         args=(_srv, ),
#    1337         name='Srv-{0}'.format(address_to_str(_srv.local_port))
#    1338     )
#
# File c:\Users\tsc95\Desktop\flask_website\.venv\lib\site-packages\sshtunnel.py:1174, in SSHTunnelForwarder._raise(self, exception, reason)
#    1172 def _raise(self, exception=BaseSSHTunnelForwarderError, reason=None):
#    1173     if self._raise_fwd_exc:
# -> 1174         raise exception(reason)
#    1175     else:
#    1176         self.logger.error(repr(exception(reason)))
#
# BaseSSHTunnelForwarderError: Could not establish session to SSH gateway

# %%
cursor, cnx, server = get_driver()
sql = f"""
        SELECT アナスロ店舗名
        FROM maptable
        Where 都道府県 = '東京都'

        """
print(sql)
cursor.execute(sql)
#myresult = cursor.fetchall()
cols = [col[0] for col in cursor.description]
map_table_anaslo_tenpo_name_df =  pd.DataFrame(cursor.fetchall(),columns = cols )
 
print(myresult)
map_table_anaslo_tenpo_name_df
# Out:
# 2023-06-30 00:26:27.916293
# local bind port: 52027
# sql connection status: True
#
#         SELECT アナスロ店舗名
#         FROM maptable
#         Where 都道府県 = '東京都'
#
#
# [('マルハン大山店',), ('メッセ笹塚店',), ('出玉本舗玉えもんお花茶屋店',), ('やすだ清水町店',), ('オリエンタルパサージュ荻窪426',), ('パラッツォ志村店',), ('阿佐ヶ谷オーシャン',), ('国際センター中村橋店',), ('国際センター中村橋店',), ('やすだ仲宿店',), ('マルハン池袋店',), ('日の出会館',), ('エスパス日拓上野新館',), ('ジャンジャン高島平駅前店',), ('エスパス日拓上野本館',), ('キング中村橋店',), ('サイバースパーク上野店',), ('フィオーレ荻窪',), ('ミリオン東武練馬13号店',), ('BBステーション日暮里店',), ('エクサ',), ('オリエンタルパサージュインペリアル本館',), ('キクヤ昭島店',), ('パーラースーパーセブン新中野店',), ('PIA上野',), ('ニラク上北台店',), ('ニラク東大和店',), ('PIA大森',), ('エスパス日拓秋葉原駅前店',), ('オゼック羽村',), ('メッセ竹の塚店',), ('つつじヶ丘ワールド',), ('ドキわくランド聖蹟桜ヶ丘店',), ('ゴードン多摩センターA館',), ('MGM国領店',), ('コンサートホール調布',), ('仙川UNO',), ('パラッツォ秋津店',), ('パーラーミツボシ祖師谷店',), ('ライオン清瀬店',), ('パーラーDAIKI三軒茶屋店',), ('国際センター千歳船橋店',), ('クラウン本店',), ('クラウン守口店',), ('クラウン守口店',), ('カレイド下北沢店',), ('秋葉原UNO',), ('コトブキホール',), ('コンサートホール志村',), ('スーパーハリウッド品川',), ('グランドホール西高島平店',), ('芝浦エイト',), ('大山オーシャン',), ('サンコー一之江店',), ('ピーアーク三田',), ('プラザ西台',), ('国際センター高田馬場店',), ('グランドシップ',), ('デラックスセブン',), ('フルハウス中延店',), ('フルハウス戸越公園店',), ('ビックディッパー門前仲町店',), ('三徳ホール',), ('シップ大島',), ('清瀬UNO',), ('ミリオン平和台16号店',), ('メッセ三鷹店',), ('オリエント秋川店',), ('K-1赤羽店',), ('ニラク武蔵村山伊奈平店',), ('エスパス日拓渋谷本館',), ('ニラク大田長原店',), ('メッセ扇店',), ('ARROW池上店',), ('エスパス日拓渋谷駅前新館',), ('エスパス日拓渋谷駅前新館',), ('エスパス日拓渋谷スロット館',), ('エスパス日拓渋谷スロット館',), ('キューデンアネックス西新井',), ('キューデンアネックス西新井',), ('キューデン東口店',), ('キューデン東口店',), ('キューデン東口店',), ('キューデン東口店',), ('ミカド五反野店',), ('エスパス日拓高田馬場本店',), ('金時蒲田東口店',), ('オアシス飯田橋店',), ('金時京急蒲田店',), ('ジアス南大沢',), ('エスパス日拓新大久保駅前店',), ('PIA八王子',), ('ピーアーク北綾瀬ピーくんガーデン',), ('ビッグスポーツ館',), ('ジャラン谷在家店',), ('ミリオン高円寺22号店',), ('エスパス日拓西武新宿駅前店',), ('京浜ホール',), ('メッセ高円寺店',), ('ジャラン五反田店',), ('ジャラン五反田店',), ('エスパス日拓新宿歌舞伎町店',), ('ビックディッパー大井町店',), ('マルシェ赤羽店',), ('MAX赤羽店',), ('MAX赤羽店',), ('ヒロキ蒲田西口店',), ('ベラジオ東十条店',), ('ベガスベガス新宿東南口店',), ('DAS東十条店',), ('マルハン八王子四谷店',), ('スロットエランドール田無店',), ('エンジェル本店',), ('ベガスベガス国分寺恋ヶ窪店',), ('トワーズ西八店',), ('ウエスタン西葛西店',), ('クリエ府中店',), ('エムディー目黒',), ('パラッツォ葛西店',), ('ウエスタン一之江店',), ('ザ・チャンス花小金井店',), ('ビーム高倉',), ('マルハン新世界店',), ('やすだひばりヶ丘店',), ('アサヒ幡ヶ谷2号店',), ('チャレンジャー福生',), ('マルシン笹塚店',), ('ニュースター一ツ家店',), ('ピーアーク竹ノ塚スタジオ',), ('マルホン',), ('マリオン新小岩店',), ('アムディ亀有',), ('ザシティベルシティ川崎店',), ('コーシン神田店',), ('ダイナム新小岩店',), ('ウエスタン葛西店',), ('ダイナム金町南口店',), ('コンサートホール荒川',), ('ロックファイブ',), ('パールショップともえ町田609',), ('オリエンタルパサージュ町田',), ('メッセ奥戸店',), ('遊劇場III',), ('AQUA H2O',), ('フォーチュンお花茶屋店',), ('ゴードン祖師谷店',), ('キコーナ府中店',), ('ダイナム東村山店',), ('イーグルR-1浅草',), ('ジャラン浅草店',), ('ダイナム武蔵境店',), ('メッセ吉祥寺店',), ('パラッツォ吉祥寺イースト店',), ('テンガイ･三鷹店',), ('三ノ輪UNO',), ('グランパ中野',), ('ニラク中野サンモール2号店',), ('フルハウス東中野店',), ('オークラ新中野店',), ('オリエンタルパサージュ自由が丘',), ('ジャパンニューアルファ池袋店',), ('甲子園池袋店',), ('パチスロ甲子園',), ('ひょうたん島',), ('PIA池袋',), ('スロットスタジアムフォーション',), ('グリンピース池袋西口店',), ('グリンピース池袋東口店',), ('グリンピース池袋東口店',), ('遊大陸池袋店',), ('パラッツォ千川店',), ('ダイナム西日暮里スロット店',), ('キューデンアネックス日暮里店',), ('ニュー太平',), ('メッセ西葛西店',), ('キコーナ平井店',), ('エクス・アリーナ東京',), ('新橋UNO',), ('ヒノマル江古田店',), ('ベガス京急蒲田店',), ('ヒノマル中目黒店',), ('ヒノマル用賀店',), ('有楽町UNO',), ('有楽町DUO',), ('パーラーディオス下赤塚本店',), ('ヒロキ3号店',), ('ヒノマル狛江店',), ('コスモ光が丘店',), ('MATSUYA SLOT ZONE',), ('MATSUYA SLOT ZONE',), ('パチンコ大学A館',), ('ヒノマル都立大１号店',), ('ヒノマル広尾店',), ('ヒノマル下丸子店',), ('四谷タイガー',), ('パーラーMAX',), ('パーラーMAX',), ('ジャンジャンマールゴット日野駅前店',), ('ニュークラウン綾瀬店',), ('P-PORT PREGO永山',), ('デルパラ7堀之内',), ('パーラーマイニチ東村山店スロット館',), ('ビーム東大和店',), ('ヒノマル駒沢店',), ('ヒノマル西小山店',), ('SANCO梅島店',), ('ヒロキ東口店',), ('戸越ミナト',), ('ゴードン永山2',), ('パーラーフィオーレ浜田山',), ('パーラーフィオーレ永福町',), ('サンフラワー瑞穂店',), ('フェイス1100瑞穂店',), ('ピーアーク北千住SSS',), ('123笹塚店',), ('メッセ荻窪店',), ('メッセ南千住店',), ('メッセ武蔵境店',), ('デルパラ6あきる野店',), ('デルパラ9東村山店',), ('楽園渋谷駅前店',), ('メッセ西荻窪店',)]
#               アナスロ店舗名
# 0             マルハン大山店
# 1              メッセ笹塚店
# 2       出玉本舗玉えもんお花茶屋店
# 3             やすだ清水町店
# 4    オリエンタルパサージュ荻窪426
# ..                ...
# 217           メッセ武蔵境店
# 218        デルパラ6あきる野店
# 219         デルパラ9東村山店
# 220           楽園渋谷駅前店
# 221           メッセ西荻窪店
#
# [222 rows x 1 columns]

# %% [markdown]
# ### parlar_dataの東京都の店舗のユニーク数を数える

# %%
cursor, cnx, server = get_driver()
sql = f"""
        SELECT DISTINCT (店舗名)
        FROM parlar_data
        Where 都道府県 = '東京都' and 日付 IN ('2023-06-28')
        """
print(sql)
cursor.execute(sql)
cols = [col[0] for col in cursor.description]
parlar_data_table_anaslo_tenpo_name_df =  pd.DataFrame(cursor.fetchall(),columns = cols )
myresult = cursor.fetchone()
print(myresult)
parlar_data_table_anaslo_tenpo_name_df
# Out:
# 2023-06-30 00:26:57.886759
# local bind port: 52040
# sql connection status: True
#
#         SELECT DISTINCT (店舗名)
#         FROM parlar_data
#         Where 都道府県 = '東京都' and 日付 IN ('2023-06-28')
#
# None
#                店舗名
# 0    レッドロック学芸大学駅前店
# 1         123+N東雲店
# 2           123笹塚店
# 3         ARROW池上店
# 4     BBステーション日暮里店
# ..             ...
# 192        金時京急蒲田店
# 193        金時大森東口店
# 194        金時蒲田東口店
# 195      阿佐ヶ谷オーシャン
# 196        飯田橋プレサス
#
# [197 rows x 1 columns]

# %% [markdown]
# ### Nの付く日三回分のデータを取得

# %%
date_list = []
day_str_list = []
today = datetime.date.today()
target_day_number = 5
target_day = today + datetime.timedelta(days=target_day_number)
today_str = today.strftime('%Y-%m-%d')
target_day_str = target_day.strftime('%Y-%m-%d')
print(target_day_str,target_day_str)
#曜日のリスト
target_day_last_char = target_day_str[-1]
target_day_text = str(target_day_last_char) + 'の付く日'
w_list = ['(月)', '(火)', '(水)', '(木)', '(金)', '(土)', '(日)']
target_day_str_jp = target_day.strftime('%m月').lstrip('0')  +target_day.strftime('%d日').lstrip('0') +  w_list[target_day.weekday()] 
print(target_day_str[-1])
day_str_list_text = ''

for i in range(39):
    belong_day = today - datetime.timedelta(days=i)
    belong_day_str = belong_day.strftime('%Y-%m-%d')

    # print(belong_day_str[-2:])
    if belong_day_str[-1] == str(target_day_str[-1]):
        if belong_day_str[-2:] == '31':
            continue
        if belong_day_str== today_str:
            continue
        day_str = belong_day.strftime('%m月%d日').lstrip('0')
        date_list.append(belong_day_str)
        day_str_list.append(day_str)
        day_str_list_text += day_str + ','
date_str = ''
for date in day_str_list[:3]:
    date_str += date + ' '

date_list_lists = date_list[:3]
day_str_list_text = str(tuple(date_list_lists))
date_str_list = []
date_str_list.append(date_str)
print(date_list_lists)
print(date_str)
print(date_str_list)
print(target_day_str_jp)
print(day_str_list_text)
prefecture = '東京都'
cursor, cnx, server = get_driver()
sql = f"""
        SELECT *
        FROM parlar_data
        Where  都道府県 = '{prefecture}' and 日付 IN {day_str_list_text}
        """
print(sql)
cursor.execute(sql)
cols = [col[0] for col in cursor.description]
parlar_data_table_anaslo_tenpo_name_df =  pd.DataFrame(cursor.fetchall(),columns = cols )
parlar_data_table_anaslo_tenpo_name_df
# Out:
# 2023-11-11 2023-11-11
# 1
# ['2023-11-01', '2023-10-21', '2023-10-11']
# 11月01日 10月21日 10月11日
# ['11月01日 10月21日 10月11日 ']
# 11月11日(土)
# ('2023-11-01', '2023-10-21', '2023-10-11')
# 2023-11-06 20:46:04.481018
# local bind port: 50282
# sql connection status: True
#
#         SELECT *
#         FROM parlar_data
#         Where  都道府県 = '東京都' and 日付 IN ('2023-11-01', '2023-10-21', '2023-10-11')
#             店舗名          日付  Nのつく日 都道府県               機種名   台番号    G数    差枚
# 0       123n東雲店  2023-10-21      1  東京都          スマスロ北斗の拳  1278  6927     0  \
# 1       123n東雲店  2023-10-21      1  東京都          スマスロ北斗の拳  1279  5198     0
# 2       123n東雲店  2023-10-21      1  東京都          スマスロ北斗の拳  1280  5815     0
# 3       123n東雲店  2023-10-21      1  東京都          スマスロ北斗の拳  1281  5644     0
# 4       123n東雲店  2023-10-21      1  東京都          スマスロ北斗の拳  1282  5824     0
# ...         ...         ...    ...  ...               ...   ...   ...   ...
# 285981  飯田橋プレサス  2023-11-01      1  東京都         スーパーリオエース   329  2325 -2078
# 285982  飯田橋プレサス  2023-11-01      1  東京都        とある科学の超電磁砲   330  1316   867
# 285983  飯田橋プレサス  2023-11-01      1  東京都             乃木坂46   331  5069 -2660
# 285984  飯田橋プレサス  2023-11-01      1  東京都     キン肉マン7人の悪魔超人編   332  6307 -3994
# 285985  飯田橋プレサス  2023-11-01      1  東京都  戦国コレクション5超極楽LOOP   333  4890  -446
#
#         BB  RB  ART     BB確率      RB確率  ART確率     合成確率        id
# 0       56  17    0  1/123.7   1/407.5  1/0.0   1/94.9  14595577
# 1       73   6    0   1/71.2   1/866.3  1/0.0   1/65.8  14595578
# 2       33  14    0  1/176.2   1/415.4  1/0.0  1/123.7  14595579
# 3       85  12    0   1/66.4   1/470.3  1/0.0   1/58.2  14595580
# 4       51  14    0  1/114.2   1/416.0  1/0.0   1/89.6  14595581
# ...     ..  ..  ...      ...       ...    ...      ...       ...
# 285981   6   2    0  1/387.5  1/1162.5         1/290.6  17365982
# 285982  57   3    0   1/23.1   1/438.7          1/21.9  17365983
# 285983  67  23    0   1/75.7   1/220.4          1/56.3  17365984
# 285984  37  14    0  1/170.5   1/450.5         1/123.7  17365985
# 285985  43   0    0  1/113.7     1/0.0         1/113.7  17365986
#
# [285986 rows x 16 columns]

# %% [markdown]
# ### 日別都道府県別のレコード数の確認

# %%
cursor, cnx, server = get_driver()
sql = f"""
        SELECT 日付, 都道府県, COUNT(DISTINCT 店舗名) AS 店舗数
        FROM parlar_data
        Where  都道府県 = '{prefecture}' and 日付 IN {day_str_list_text}
        GROUP BY  都道府県, 日付
        """
print(sql)
cursor.execute(sql)
cols = [col[0] for col in cursor.description]
parlar_data_table_anaslo_tenpo_name_df =  pd.DataFrame(cursor.fetchall(),columns = cols )
parlar_data_table_anaslo_tenpo_name_df
# Out:
# 2023-11-06 20:46:41.613018
# local bind port: 50326
# sql connection status: True
#
#         SELECT 日付, 都道府県, COUNT(DISTINCT 店舗名) AS 店舗数
#         FROM parlar_data
#         Where  都道府県 = '東京都' and 日付 IN ('2023-11-01', '2023-10-21', '2023-10-11')
#         GROUP BY  都道府県, 日付
#            日付 都道府県  店舗数
# 0  2023-10-11  東京都  212
# 1  2023-10-21  東京都  211
# 2  2023-11-01  東京都  208

# %%
cursor = get_driver()
prefecture = '神奈川県'
target_day = '2023-11-03'
print('prefectureは',prefecture)
cursor.execute(f'''SELECT *
            FROM schedule as schedule2
            left join halldata as halldata2
            on schedule2.店舗名 = halldata2.hall_name
            WHERE イベント日 = '{target_day}'
            AND 媒体名 != 'ホールナビ'
            AND 媒体名 != '旧イベ'
            AND 都道府県 = '{prefecture}'
            ORDER BY イベント日,都道府県 desc;''')
cols = [col.name for col in cursor.description]
extract_prefecture_name_df = pd.DataFrame(cursor.fetchall(),columns=cols)
extract_prefecture_name_df.drop_duplicates(keep='first',inplace=True)
extract_prefecture_name_df
# Out:
# 2023-11-03 01:59:38.943014
# local bind port: 64175
# sql connection status: True
# prefectureは 神奈川県
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\tsc95\Desktop\flask_website\test\sql_table_join_practice.ipynb セル 16 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X53sZmlsZQ%3D%3D?line=2'>3</a> target_day = '2023-11-03'
#       <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X53sZmlsZQ%3D%3D?line=3'>4</a> print('prefectureは',prefecture)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X53sZmlsZQ%3D%3D?line=4'>5</a> cursor.execute(f'''SELECT *
#       <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X53sZmlsZQ%3D%3D?line=5'>6</a>             FROM schedule as schedule2
#       <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X53sZmlsZQ%3D%3D?line=6'>7</a>             left join halldata as halldata2
#       <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X53sZmlsZQ%3D%3D?line=7'>8</a>             on schedule2.店舗名 = halldata2.hall_name
#       <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X53sZmlsZQ%3D%3D?line=8'>9</a>             WHERE イベント日 = '{target_day}'
#      <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X53sZmlsZQ%3D%3D?line=9'>10</a>             AND 媒体名 != 'ホールナビ'
#      <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X53sZmlsZQ%3D%3D?line=10'>11</a>             AND 媒体名 != '旧イベ'
#      <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X53sZmlsZQ%3D%3D?line=11'>12</a>             AND 都道府県 = '{prefecture}'
#      <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X53sZmlsZQ%3D%3D?line=12'>13</a>             ORDER BY イベント日,都道府県 desc;''')
#      <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X53sZmlsZQ%3D%3D?line=13'>14</a> cols = [col.name for col in cursor.description]
#      <a href='vscode-notebook-cell:/c%3A/Users/tsc95/Desktop/flask_website/test/sql_table_join_practice.ipynb#X53sZmlsZQ%3D%3D?line=14'>15</a> extract_prefecture_name_df = pd.DataFrame(cursor.fetchall(),columns=cols)
#
# AttributeError: 'tuple' object has no attribute 'execute'

# %%
cursor, cnx, server = get_driver()
#parlar_dataテーブルの10月4日の都道府県別の店舗数のデータを取得
sql = f"""
        SELECT 日付, 都道府県, COUNT(DISTINCT 店舗名) AS 店舗数
        FROM parlar_data
        Where 都道府県 in  ('埼玉県' , '東京都' ,  '千葉県' , '神奈川県' ) and 日付 IN ('2023-10-07')
        GROUP BY  都道府県, 日付
        """
print(sql)
cursor.execute(sql)
cols = [col[0] for col in cursor.description]
parlar_data_table_anaslo_tenpo_name_df =  pd.DataFrame(cursor.fetchall(),columns = cols )
parlar_data_table_anaslo_tenpo_name_df

# #parlar_dataテーブルの10月4日のデータを削除
# cursor, cnx, server = get_driver()
# sql = f"""
#         DELETE
#         FROM parlar_data
#         Where 日付 IN ('2023-10-04')
#         """
# print(sql)
# cursor.execute(sql)
# cnx.commit()
# Out:
# 2023-11-02 23:59:30.329213
# local bind port: 58041
# sql connection status: True
#
#         SELECT 日付, 都道府県, COUNT(DISTINCT 店舗名) AS 店舗数
#         FROM parlar_data
#         Where 都道府県 in  ('埼玉県' , '東京都' ,  '千葉県' , '神奈川県' ) and 日付 IN ('2023-10-07')
#         GROUP BY  都道府県, 日付
#            日付 都道府県  店舗数
# 0  2023-10-07  東京都  201

# %%
date_list = []
day_str_list = []
today = datetime.date.today()

target_day = today + datetime.timedelta(days=target_day_number)
target_day_str = target_day.strftime('%Y-%m-%d')
print(target_day_str,target_day_str)
#曜日のリスト
target_day_last_char = target_day_str[-1]
target_day_text = str(target_day_last_char) + 'の付く日'
w_list = ['(月)', '(火)', '(水)', '(木)', '(金)', '(土)', '(日)']
target_day_str_jp = target_day.strftime('%m月').lstrip('0')  +target_day.strftime('%d日').lstrip('0') +  w_list[target_day.weekday()] 
print(target_day_str[-1])


for i in range(39):
    belong_day = today - datetime.timedelta(days=i)
    belong_day_str = belong_day.strftime('%Y-%m-%d')

    # print(belong_day_str[-2:])
    if belong_day_str[-1] == str(target_day_str[-1]):
        if belong_day_str[-2:] == '31':
            continue
        day_str = belong_day.strftime('%m月%d日').lstrip('0')
        date_list.append(belong_day_str)
        day_str_list.append(day_str)
date_str = ''
for date in day_str_list[:3]:
    date_str += date + ' '

date_list_lists = date_list[:3]

date_str_list = []
date_str_list.append(date_str)
print(date_list_lists)
print(date_str)
print(date_str_list)
print(target_day_str_jp)


cursor, cnx, server = get_driver()
sql = f"""
        SELECT DISTINCT (店舗名)
        FROM parlar_data
        Where 都道府県 = '東京都' and 日付 IN ('2023-06-28')
        """
print(sql)
cursor.execute(sql)
cols = [col[0] for col in cursor.description]
parlar_data_table_anaslo_tenpo_name_df =  pd.DataFrame(cursor.fetchall(),columns = cols )
myresult = cursor.fetchone()
print(myresult)
parlar_data_table_anaslo_tenpo_name_df

# %% [markdown]
# ### maptableとparlar_dataのテーブル間の店舗名の差分を出す

# %%
print('parlar_data_table_anaslo_tenpo_name_df',len(parlar_data_table_anaslo_tenpo_name_df['店舗名']))
print('map_table_anaslo_tenpo_name_df',len(map_table_anaslo_tenpo_name_df['アナスロ店舗名']))
diff_tenpo_name_list = list(set(map_table_anaslo_tenpo_name_df['アナスロ店舗名'])- set(parlar_data_table_anaslo_tenpo_name_df['店舗名']))
print(len(diff_tenpo_name_list))
sorted(diff_tenpo_name_list)
# Out:
# parlar_data_table_anaslo_tenpo_name_df 197
# map_table_anaslo_tenpo_name_df 222
# 88
# ['AQUA H2O',
#  'DAS東十条店',
#  'K-1赤羽店',
#  'MATSUYA SLOT ZONE',
#  'MAX赤羽店',
#  'MGM国領店',
#  'P-PORT PREGO永山',
#  'やすだひばりヶ丘店',
#  'やすだ仲宿店',
#  'やすだ清水町店',
#  'イーグルR-1浅草',
#  'エクス・アリーナ東京',
#  'エスパス日拓渋谷スロット館',
#  'エンジェル本店',
#  'オゼック羽村',
#  'オリエンタルパサージュインペリアル本館',
#  'オリエンタルパサージュ町田',
#  'キング中村橋店',
#  'クラウン守口店',
#  'クラウン本店',
#  'グリンピース池袋東口店',
#  'グリンピース池袋西口店',
#  'ゴードン多摩センターA館',
#  'ゴードン祖師谷店',
#  'サイバースパーク上野店',
#  'サンコー一之江店',
#  'サンフラワー瑞穂店',
#  'ザシティベルシティ川崎店',
#  'シップ大島',
#  'スロットスタジアムフォーション',
#  'ダイナム新小岩店',
#  'ダイナム東村山店',
#  'ダイナム武蔵境店',
#  'ダイナム西日暮里スロット店',
#  'ダイナム金町南口店',
#  'チャレンジャー福生',
#  'デラックスセブン',
#  'デルパラ6あきる野店',
#  'デルパラ9東村山店',
#  'ドキわくランド聖蹟桜ヶ丘店',
#  'ニュークラウン綾瀬店',
#  'ニラク上北台店',
#  'ニラク中野サンモール2号店',
#  'ニラク大田長原店',
#  'ニラク東大和店',
#  'ニラク武蔵村山伊奈平店',
#  'パチスロ甲子園',
#  'パチンコ大学A館',
#  'パラッツォ吉祥寺イースト店',
#  'パーラーDAIKI三軒茶屋店',
#  'パーラーMAX',
#  'パーラーディオス下赤塚本店',
#  'パーラーフィオーレ永福町',
#  'パーラーフィオーレ浜田山',
#  'パーラーマイニチ東村山店スロット館',
#  'パーラーミツボシ祖師谷店',
#  'ヒノマル下丸子店',
#  'ヒノマル中目黒店',
#  'ヒノマル広尾店',
#  'ヒノマル江古田店',
#  'ヒノマル狛江店',
#  'ヒノマル用賀店',
#  'ヒノマル西小山店',
#  'ヒノマル都立大１号店',
#  'ヒノマル駒沢店',
#  'ビッグスポーツ館',
#  'ビーム東大和店',
#  'ビーム高倉',
#  'フィオーレ荻窪',
#  'フェイス1100瑞穂店',
#  'フォーチュンお花茶屋店',
#  'フルハウス戸越公園店',
#  'フルハウス東中野店',
#  'ベガスベガス国分寺恋ヶ窪店',
#  'ベガスベガス新宿東南口店',
#  'マルシェ赤羽店',
#  'マルシン笹塚店',
#  'マルハン新世界店',
#  'ミカド五反野店',
#  'ライオン清瀬店',
#  'ロックファイブ',
#  '三徳ホール',
#  '出玉本舗玉えもんお花茶屋店',
#  '国際センター千歳船橋店',
#  '日の出会館',
#  '甲子園池袋店',
#  '芝浦エイト',
#  '遊大陸池袋店']

# %% [markdown]
# ### 各テーブルの東京都の店舗リストの集合差をSQLで出す

# %%
cursor, cnx, server = get_driver()
sql = f"""
SELECT maptable.都道府県
  FROM maptable 
  Where 都道府県 = '東京都'
  INNER JOIN b
    ON a.id = b.id
        """
print(sql)
cursor.execute(sql)
cols = [col[0] for col in cursor.description]
temp_df =  pd.DataFrame(cursor.fetchall(),columns = cols )
myresult = cursor.fetchone()
print(myresult)
temp_df
# Out:
# 2023-06-29 16:11:02.511626
# local bind port: 61843
# sql connection status: True
#
# SELECT maptable.都道府県
#   FROM maptable
#   Where 都道府県 = '東京都'
#   INNER JOIN b
#     ON a.id = b.id
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[21], line 10
#       2 sql = f"""
#       3 SELECT maptable.都道府県
#       4   FROM maptable
#    (...)
#       7     ON a.id = b.id
#       8         """
#       9 print(sql)
# ---> 10 cursor.execute(sql)
#      12 temp_df =  pd.DataFrame(cursor.fetchall(),columns = ['id','取材名','媒体名','公約内容','取得時間'])
#      13 myresult = cursor.fetchone()
#
# File c:\Users\tsc95\Desktop\flask_website\.venv\lib\site-packages\mysql\connector\cursor.py:572, in MySQLCursor.execute(self, operation, params, multi)
#     569     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     571 try:
# --> 572     self._handle_result(self._connection.cmd_query(stmt))
#     573 except errors.InterfaceError:
#     574     if self._connection._have_next_result:  # pylint: disable=W0212
#
# File c:\Users\tsc95\Desktop\flask_website\.venv\lib\site-packages\mysql\connector\connection.py:922, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     920 query = bytes(packet)
#     921 try:
# --> 922     result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     923 except errors.ProgrammingError as err:
#     924     if err.errno == 3948 and \
#     925        "Loading local data is disabled" in err.msg:
#
# File c:\Users\tsc95\Desktop\flask_website\.venv\lib\site-packages\mysql\connector\connection.py:732, in MySQLConnection._handle_result(self, packet)
#     730     return self._handle_eof(packet)
#     731 elif packet[4] == 255:
# --> 732     raise errors.get_exception(packet)
#     734 # We have a text result set
#     735 column_count = self._protocol.parse_column_count(packet)
#
# ProgrammingError: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'INNER JOIN b
#     ON a.id = b.id' at line 4

# %% [markdown]
# ### 公約管理のテーブル表示

# %%
sql = f"""
        SELECT *
        FROM pledge
        """
print(sql)
cursor.execute(sql)
#cols = [col[0] for col in cursor.description]
sql_syuzai_report_all_df = pd.DataFrame(cursor.fetchall(),columns = ['id','取材名','媒体名','公約内容','取得時間'])
sql_syuzai_report_all_df
# Out:
#         SELECT *
#         FROM pledge
#           id              取材名         媒体名            公約内容                取得時間
# 0          1          ｙｔｒ来店実践    SEVENSTV            来店実践 2023-03-16 03:56:31
# 1          2            Ａレポート         アツ姫      Aタイプに高設定投入 2023-03-16 03:56:31
# 2          3    黒バラの極意(来店ver)    ジャンバリ.TV                 2023-03-16 03:56:31
# 3          4           鮮魚レポート        アメスロ                 2023-03-16 03:56:31
# 4          5  魔法少女レポート スロット取材        爆ガチ！  まどかマギカシリーズが狙い目 2023-03-16 03:56:31
# ...      ...              ...         ...             ...                 ...
# 2126  101375           しおねえ来店       エースプロ            None 2023-06-17 09:30:52
# 2127  101376        星のパチは友を呼ぶ  パチとスロは友を呼ぶ            None 2023-06-18 09:25:03
# 2128  101377          シーサ。の法則    P-martTV            None 2023-06-24 01:48:28
# 2129  101378           ジョージ来店    その他取材・企画            None 2023-06-24 01:48:28
# 2130  101379        萌えジャックNEO         アツ姫            None 2023-06-24 01:48:28
#
# [2131 rows x 5 columns]

# %% [markdown]
# ### 過去一週間の東京都の取材予定と結果を表示する

# %%
cursor, cnx, server = get_driver()
sql = f"""
        SELECT 店舗名,SUM(差枚),SUM(差枚)/COUNT(*),COUNT(*)
        FROM parlar_data
        Where 都道府県 = '東京都' and 日付 IN ('2023-06-28')
        group by 店舗名
        """
print(sql)
cursor.execute(sql)
cols = [col[0] for col in cursor.description]
parlar_data_table_anaslo_tenpo_name_df =  pd.DataFrame(cursor.fetchall(),columns = cols )
myresult = cursor.fetchone()
print(myresult)
parlar_data_table_anaslo_tenpo_name_df
# Out:
# 2023-07-08 00:29:57.110369
# local bind port: 65088
# sql connection status: True
#
#         SELECT 店舗名,SUM(差枚),SUM(差枚)/COUNT(*),COUNT(*)
#         FROM parlar_data
#         Where 都道府県 = '東京都' and 日付 IN ('2023-06-28')
#         group by 店舗名
#
# None
#               店舗名 SUM(差枚) SUM(差枚)/COUNT(*)  COUNT(*)
# 0        123+N東雲店  -62471        -161.4238       387
# 1          123笹塚店  -16933         -84.6650       200
# 2        ARROW池上店  -15766         -56.3071       280
# 3    BBステーション日暮里店   -5229         -35.8151       146
# 4        G-ONE吉祥寺   -4073         -25.4563       160
# ..            ...     ...              ...       ...
# 192       金時京急蒲田店   -4728         -40.7586       116
# 193       金時大森東口店  -28250        -156.0773       181
# 194       金時蒲田東口店    3360          25.2632       133
# 195     阿佐ヶ谷オーシャン   17537         102.5556       171
# 196       飯田橋プレサス   25262         148.6000       170
#
# [197 rows x 4 columns]

# %%
cursor, cnx, server = get_driver()
sql = f"""
        SELECT *
        FROM schedule
        Where 都道府県 = '東京都' and イベント日 IN ('2023-06-28')
        """
print(sql)
cursor.execute(sql)
cols = [col[0] for col in cursor.description]
report_df =  pd.DataFrame(cursor.fetchall(),columns = cols )
myresult = cursor.fetchone()
print(myresult)
report_df.head()
# Out:
# 2023-07-08 00:30:01.362402
# local bind port: 65097
# sql connection status: True
#
#         SELECT *
#         FROM schedule
#         Where 都道府県 = '東京都' and イベント日 IN ('2023-06-28')
#
# None
#       id 都道府県       イベント日 曜日            店舗名                        取材名
# 0  51512  東京都  2023-06-28  水        ジュラク王子店   ナビ子AI予想【差枚プラス】★3 (8のつく日)  \
# 1  51514  東京都  2023-06-28  水        グランドシップ             旧イベ過去状況評価 加点なし
# 2  51570  東京都  2023-06-28  水          仙川UNO                    昇天チャレンジ
# 3  51714  東京都  2023-06-28  水         PIA八王子               Bakyun!スケールL
# 4  51730  東京都  2023-06-28  水  ビックディッパー新橋1号店  ナビ子AI予想【差枚プラス】★3 (毎週 水曜日)
#
#        媒体名 取材ランク       取得時間
# 0    ホールナビ     S 2023-06-30
# 1    ホールナビ     ・ 2023-06-30
# 2    えいりヤン     C 2023-06-30
# 3  パチスロ必勝本     ・ 2023-06-30
# 4    ホールナビ     S 2023-06-30

# %%
cursor, cnx, server = get_driver()
sql = f"""
        SELECT *
        FROM parlar_data 
        LEFT JOIN  maptable 
        on parlar_data.店舗名 = maptable.アナスロ店舗名
        Where  日付 IN ('2023-06-28') 
        limit 10
        
        """
print(sql)
cursor.execute(sql)
cols = [col[0] for col in cursor.description]
report_df =  pd.DataFrame(cursor.fetchall(),columns = cols )
myresult = cursor.fetchone()
print(myresult)
report_df.head()


# SELECT * FROM テーブル1
# JOIN テーブル2 ON テーブル1.user_id = テーブル2.user_id
# JOIN テーブル3 ON テーブル1.user_id = テーブル3.user_id
# WHERE テーブル1.user_id = 値
# Out:
# 2023-07-08 00:30:07.617452
# local bind port: 65109
# sql connection status: True
#
#         SELECT *
#         FROM parlar_data
#         LEFT JOIN  maptable
#         on parlar_data.店舗名 = maptable.アナスロ店舗名
#         Where  日付 IN ('2023-06-28')
#         limit 10
#
#
# None
#           店舗名          日付  Nのつく日  都道府県       機種名   台番号    G数   差枚  BB  RB
# 0  エスパス日拓上野新館  2023-06-28      8   東京都  マイジャグラーV  2013   571 -300   2   0  \
# 1  エスパス日拓上野新館  2023-06-28      8   東京都  マイジャグラーV  2014  3783 -600  10  11
# 2  エスパス日拓上野新館  2023-06-28      8   東京都  マイジャグラーV  2015   977  600   7   0
# 3  エスパス日拓上野新館  2023-06-28      8   東京都  マイジャグラーV  2016  6282  500  24  23
# 4  エスパス日拓上野新館  2023-06-28      8   東京都  マイジャグラーV  2017  3136 -400  10  10
#
#    ...  都道府県 kintone_id shop_id    ホールナビ店舗名      DMM店舗名     アナスロ店舗名       緯度
# 0  ...   東京都     P00102     102  エスパス日拓上野新館  エスパス日拓上野新館  エスパス日拓上野新館  35.7093  \
# 1  ...   東京都     P00102     102  エスパス日拓上野新館  エスパス日拓上野新館  エスパス日拓上野新館  35.7093
# 2  ...   東京都     P00102     102  エスパス日拓上野新館  エスパス日拓上野新館  エスパス日拓上野新館  35.7093
# 3  ...   東京都     P00102     102  エスパス日拓上野新館  エスパス日拓上野新館  エスパス日拓上野新館  35.7093
# 4  ...   東京都     P00102     102  エスパス日拓上野新館  エスパス日拓上野新館  エスパス日拓上野新館  35.7093
#
#         経度                       住所                取得時間
# 0  139.774  東京都台東区上野4-7-5　日拓上野アメ横ビル 2023-03-18 05:36:44
# 1  139.774  東京都台東区上野4-7-5　日拓上野アメ横ビル 2023-03-18 05:36:44
# 2  139.774  東京都台東区上野4-7-5　日拓上野アメ横ビル 2023-03-18 05:36:44
# 3  139.774  東京都台東区上野4-7-5　日拓上野アメ横ビル 2023-03-18 05:36:44
# 4  139.774  東京都台東区上野4-7-5　日拓上野アメ横ビル 2023-03-18 05:36:44
#
# [5 rows x 27 columns]

# %%
prefecture = '埼玉県'

#イベント日,店舗名,取材名,媒体名,アナスロ店舗名
cursor, cnx, server = get_driver()
sql = f"""SELECT イベント日,店舗名,取材名,媒体名,アナスロ店舗名,経度,緯度,取材ランク
        FROM schedule as schedule2
        left join maptable as maptable2
        on schedule2.店舗名 = maptable2.アナスロ店舗名
                where schedule2.都道府県 = '{prefecture}' and schedule2.イベント日 IN ('2023-07-07') and schedule2.媒体名 != 'ホールナビ' 
        """
print(sql)
cursor.execute(sql)
cols = [col[0] for col in cursor.description]
report_df =  pd.DataFrame(cursor.fetchall(),columns = cols )
report_df = report_df.drop_duplicates(keep='first')
report_df =report_df.dropna(subset=['経度'])
report_df.head(20)
# Out:
# 2023-07-08 00:30:13.723874
# local bind port: 65122
# sql connection status: True
# SELECT イベント日,店舗名,取材名,媒体名,アナスロ店舗名,経度,緯度,取材ランク
#         FROM schedule as schedule2
#         left join maptable as maptable2
#         on schedule2.店舗名 = maptable2.アナスロ店舗名
#                 where schedule2.都道府県 = '埼玉県' and schedule2.イベント日 IN ('2023-07-07') and schedule2.媒体名 != 'ホールナビ'
#          イベント日          店舗名              取材名         媒体名      アナスロ店舗名
# 0   2023-07-07      ダイナム児玉店       旧イベ(7のつく日)         旧イベ      ダイナム児玉店  \
# 1   2023-07-07  第一プラザ坂戸1000             実践収録        ミリテレ  第一プラザ坂戸1000
# 3   2023-07-07     アリーナ美女木店  あゆちゃんまんプロデュース屋台      エリアイ企画     アリーナ美女木店
# 5   2023-07-07      マルハン入間店       旧イベ(7のつく日)         旧イベ      マルハン入間店
# 6   2023-07-07      マルハン入間店        ガチアンケート虹色        ガチアン      マルハン入間店
# 8   2023-07-07      マルハン川越店        ガチアンケート虹色        ガチアン      マルハン川越店
# 9   2023-07-07      マルハン川越店       旧イベ(7のつく日)         旧イベ      マルハン川越店
# 12  2023-07-07   第一プラザみずほ台店         新回胴ミッション    新回胴ミッション   第一プラザみずほ台店
# 13  2023-07-07   第一プラザみずほ台店         新回胴ミッション    新回胴ミッション   第一プラザみずほ台店
# 14  2023-07-07     パラッツォ川越店        ガチアンケート虹色        ガチアン     パラッツォ川越店
# 15  2023-07-07     パラッツォ川越店         新回胴ミッション    新回胴ミッション     パラッツォ川越店
# 17  2023-07-07     パラッツォ川越店         新回胴ミッション    新回胴ミッション     パラッツォ川越店
# 18  2023-07-07      ピーアーク草加          昇天チャレンジ       えいりヤン      ピーアーク草加
# 19  2023-07-07      マルハン上里店       旧イベ(7のつく日)         旧イベ      マルハン上里店
# 21  2023-07-07      ピーアーク新田          昇天チャレンジ       えいりヤン      ピーアーク新田
# 22  2023-07-07      ピーアーク新田          昇天チャレンジ       えいりヤン      ピーアーク新田
# 24  2023-07-07      ピーアーク松原          昇天チャレンジ       えいりヤン      ピーアーク松原
# 25  2023-07-07     ピーアーク春日部      リニューアル(3日目)  リニューアルオープン     ピーアーク春日部
# 27  2023-07-07        PIA川口             四神青龍          四神        PIA川口
# 28  2023-07-07        PIA川口       旧イベ(7のつく日)         旧イベ        PIA川口
#
#          経度       緯度 取材ランク
# 0   139.136  36.1995     ・
# 1   139.419  35.9656     C
# 3   139.635  35.8305     C
# 5   139.376  35.8161     ・
# 6   139.376  35.8161     B
# 8   139.470  35.8867     B
# 9   139.470  35.8867     ・
# 12  139.551  35.8391     C
# 13  139.551  35.8391     ・
# 14  139.484  35.9159     B
# 15  139.484  35.9159     C
# 17  139.484  35.9159     ・
# 18  139.803  35.8288     ・
# 19  139.138  36.2597     ・
# 21  139.795  35.8531     C
# 22  139.795  35.8531     ・
# 24  139.801  35.8439     ・
# 25  139.754  35.9790     ・
# 27  139.718  35.8029     B
# 28  139.718  35.8029     ・

# %% [markdown]
# ### foliumライブラリを使ってHTML上にマップとピンを表示する

# %%
def convert_date(date):
    date = str(date).split('-')
    date = date[1].lstrip('0') + '月' + date[2].lstrip('0')+ '日'
    return date
report_df['イベント日_JP'] = report_df['イベント日'].map(convert_date)
report_df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 5
#       3     date = date[1].lstrip('0') + '月' + date[2].lstrip('0')+ '日'
#       4     return date
# ----> 5 report_df['イベント日_JP'] = report_df['イベント日'].map(convert_date)
#       6 report_df
#
# File c:\Users\tsc95\Desktop\flask_website\.venv\lib\site-packages\pandas\core\series.py:4393, in Series.map(self, arg, na_action)
#    4314 def map(
#    4315     self,
#    4316     arg: Callable | Mapping | Series,
#    4317     na_action: Literal["ignore"] | None = None,
#    4318 ) -> Series:
#    4319     """
#    4320     Map values of Series according to an input mapping or function.
#    4321
#    (...)
#    4391     dtype: object
#    4392     """
# -> 4393     new_values = self._map_values(arg, na_action=na_action)
#    4394     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4395         self, method="map"
#    4396     )
#
# File c:\Users\tsc95\Desktop\flask_website\.venv\lib\site-packages\pandas\core\base.py:924, in IndexOpsMixin._map_values(self, mapper, na_action)
#     921         raise ValueError(msg)
#     923 # mapper is a function
# --> 924 new_values = map_f(values, mapper)
#     926 return new_values
#
# File c:\Users\tsc95\Desktop\flask_website\.venv\lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[12], line 3, in convert_date(date)
#       1 def convert_date(date):
#       2     date = str(date).split('-')
# ----> 3     date = date[1].lstrip('0') + '月' + date[2].lstrip('0')+ '日'
#       4     return date
#
# IndexError: list index out of range

# %% [markdown]
# S=赤色
# A=緑色
# B=黄色
# C=青色

# %%
icon=folium.Icon(color="orange")

# %%
report_df['アナスロ店舗名'].unique()
# Out:
# array(['マルハン川越店', '第一プラザみずほ台店', 'パラッツォ川越店', 'ピーアーク草加', 'ピーアーク松原',
#        'ピーアーク春日部', 'アリーナ岩槻本店', 'パラッツォ蕨店', 'ピーアーク越谷', 'パラッツォ三郷中央店',
#        'パラッツォ鳩ヶ谷店', '上福岡UNO', '第一プラザ西浦和店', 'スーパーライブガーデン行田店', '上尾UNO'],
#       dtype=object)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import datetime
import time
import unicodedata
import string
import requests
from folium import plugins
import branca
from PIL import Image, ImageDraw, ImageFont
import folium
from folium.features import CustomIcon
# 地図生成

if prefecture == '神奈川県':
    prefecture_latitude = 35.44778
    prefecture_longitude = 139.64250
elif prefecture == '東京都':
    prefecture_latitude = 35.68944
    prefecture_longitude = 139.69167
elif prefecture == '千葉県':
    prefecture_latitude = 35.60472
    prefecture_longitude = 140.12333
elif prefecture == '埼玉県':
    prefecture_latitude = 35.85694
    prefecture_longitude = 139.64889
elif prefecture == '茨城県':
    prefecture_latitude = 36.34139
    prefecture_longitude = 140.44667
else:
    pass

folium_map = folium.Map(location=[prefecture_latitude,prefecture_longitude], zoom_start=10)
# 地図表示
# マーカープロット（ポップアップ設定，色変更，アイコン変更）
for tenpo_name in report_df['アナスロ店舗名'].unique():
    print(tenpo_name)
    extract_syuzai_df_1 = report_df[report_df['アナスロ店舗名'] == tenpo_name]
    #display(extract_syuzai_df_1)
    syuzai_rank_list = list(extract_syuzai_df_1['取材ランク'].unique())
    #print(syuzai_rank_list)
    
    latitude = extract_syuzai_df_1.iloc[0]['緯度']
    longitude = extract_syuzai_df_1.iloc[0]['経度']


    # グレースケールの画像データを作成
    im = Image.new("L", (130, 25),color=(55))

    # 画像の表示
    im.putalpha(100)
    # 描画準備
    draw = ImageDraw.Draw(im)
    font = ImageFont.truetype('font\LightNovelPOPv2.otf',10)
    if len(extract_syuzai_df_1)==1:
        syuzai_name_text = '◆' + tenpo_name + f'\n {extract_syuzai_df_1["取材名"].values[0]}'
    else:
        syuzai_name_text = '◆' + tenpo_name + f'\n {extract_syuzai_df_1["取材名"].values[0]}、他{len(extract_syuzai_df_1)-1}件'
    #print(syuzai_name_text)
    draw.multiline_text(
        (60, 0),
        f'{syuzai_name_text}',
        font=font,
        fill='white',
        align='center',
        spacing=0,
        anchor='ma'
    )
    # 画像を表示
    im.save('syuzai_image.png', quality=95)
    img = 'syuzai_image.png'
    popup_df = folium.Popup(
    extract_syuzai_df_1[['イベント日','店舗名','取材名','媒体名']].to_html(), 
    width=500, 
    height=300)

    folium.Marker(location=[latitude ,longitude],
        popup=popup_df,
        max_height=200,
        icon = CustomIcon(
                    icon_image = img,
                    icon_size = (130, 25),
                    icon_anchor = (0, 0),
                    #shadow_image = shadow_img, # 影効果（今回は使用せず コメントアウト
                    #shadow_size = (30, 30),
                    shadow_anchor = (-4, -40),
                    popup_anchor = (3, 3))).add_to(folium_map)
    #break
folium_map.save(outfile="./output_map.html")
folium_map
# Out:
# 第一プラザ坂戸1000
# アリーナ美女木店
# マルハン川越店
# 第一プラザみずほ台店
# パラッツォ川越店
# ピーアーク草加
# ピーアーク新田
# ピーアーク松原
# ピーアーク春日部
# PIA川口
# アリーナ岩槻本店
# ピーアーク朝霞
# パラッツォ蕨店
# ピーアークせんげん台
# ピーアーク越谷
# パラッツォ三郷中央店
# やすだ所沢店
# やすだ三郷店
# 楽園大宮店
# パラッツォ鳩ヶ谷店
# 虹のある街川口店
# 上福岡UNO
# 第一プラザ西浦和店
# スーパーライブガーデン行田店
# セイブゾーン
# オータ志木駅前店
# 上尾UNO
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4d73ce6c1fc9154adaea9e6edc4222a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4d73ce6c1fc9154adaea9e6edc4222a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4d73ce6c1fc9154adaea9e6edc4222a = L.map(
#                 &quot;map_c4d73ce6c1fc9154adaea9e6edc4222a&quot;,
#                 {
#                     center: [35.85694, 139.64889],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56a904fa40ca51329d9fcccdef23fda4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c4d73ce6c1fc9154adaea9e6edc4222a);
#
#
#             var marker_ac0734a01ad2df558bc96647275e2ee7 = L.marker(
#                 [35.9656, 139.419],
#                 {&quot;maxHeight&quot;: 200}
#             ).addTo(map_c4d73ce6c1fc9154adaea9e6edc4222a);
#
#
#         var custom_icon_7dd05b8726e9dc9a646f67125dcbdd3f = L.icon({&quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [130, 25], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3], &quot;shadowAnchor&quot;: [-4, -40]});
#         marker_ac0734a01ad2df558bc96647275e2ee7.setIcon(custom_icon_7dd05b8726e9dc9a646f67125dcbdd3f);
#
#
#         var popup_4336cb55404172d31473cfe02f89f4bf = L.popup({&quot;height&quot;: 300, &quot;maxWidth&quot;: &quot;100%&quot;, &quot;width&quot;: 500});
#
#
#
#                 var html_3494f28899f12236ecb610727411e97b = $(`&lt;div id=&quot;html_3494f28899f12236ecb610727411e97b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table border=&quot;1&quot; class=&quot;dataframe&quot;&gt;   &lt;thead&gt;     &lt;tr style=&quot;text-align: right;&quot;&gt;       &lt;th&gt;&lt;/th&gt;       &lt;th&gt;イベント日&lt;/th&gt;       &lt;th&gt;店舗名&lt;/th&gt;       &lt;th&gt;取材名&lt;/th&gt;       &lt;th&gt;媒体名&lt;/th&gt;     &lt;/tr&gt;   &lt;/thead&gt;   &lt;tbody&gt;     &lt;tr&gt;       &lt;th&gt;0&lt;/th&gt;       &lt;td&gt;2023-07-07&lt;/td&gt;       &lt;td&gt;第一プラザ坂戸1000&lt;/td&gt;       &lt;td&gt;実践収録&lt;/td&gt;       &lt;td&gt;ミリテレ&lt;/td&gt;     &lt;/tr&gt;   &lt;/tbody&gt; &lt;/table&gt;&lt;/div&gt;`)[0];
#                 popup_4336cb55404172d31473cfe02f89f4bf.setContent(html_3494f28899f12236ecb610727411e97b);
#
#
#
#         marker_ac0734a01ad2df558bc96647275e2ee7.bindPopup(popup_4336cb55404172d31473cfe02f89f4bf)
#         ;
#
#
#
#
#             var marker_542e27931b297ac8b2222a9340143a93 = L.marker(
#                 [35.8305, 139.635],
#                 {&quot;maxHeight&quot;: 200}
#             ).addTo(map_c4d73ce6c1fc9154adaea9e6edc4222a);
#
#
#         var custom_icon_3cbc8006627055a30b1b4e89ef02fbec = L.icon({&quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [130, 25], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3], &quot;shadowAnchor&quot;: [-4, -40]});
#         marker_542e27931b297ac8b2222a9340143a93.setIcon(custom_icon_3cbc8006627055a30b1b4e89ef02fbec);
#
#
#         var popup_51cc48b99c5aca53dad6bbe89f286c70 = L.popup({&quot;height&quot;: 300, &quot;maxWidth&quot;: &quot;100%&quot;, &quot;width&quot;: 500});
#
#
#
#                 var html_9460f84a29a89c485fb9bde5ab0953bb = $(`&lt;div id=&quot;html_9460f84a29a89c485fb9bde5ab0953bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table border=&quot;1&quot; class=&quot;dataframe&quot;&gt;   &lt;thead&gt;     &lt;tr style=&quot;text-align: right;&quot;&gt;       &lt;th&gt;&lt;/th&gt;       &lt;th&gt;イベント日&lt;/th&gt;       &lt;th&gt;店舗名&lt;/th&gt;       &lt;th&gt;取材名&lt;/th&gt;       &lt;th&gt;媒体名&lt;/th&gt;     &lt;/tr&gt;   &lt;/thead&gt;   &lt;tbody&gt;     &lt;tr&gt;       &lt;th&gt;1&lt;/th&gt;       &lt;td&gt;2023-07-07&lt;/td&gt;       &lt;td&gt;アリーナ美女木店&lt;/td&gt;       &lt;td&gt;あゆちゃんまんプロデュース屋台&lt;/td&gt;       &lt;td&gt;エリアイ企画&lt;/td&gt;     &lt;/tr&gt;   &lt;/tbody&gt; &lt;/table&gt;&lt;/div&gt;`)[0];
#                 popup_51cc48b99c5aca53dad6bbe89f286c70.setContent(html_9460f84a29a89c485fb9bde5ab0953bb);
#
#
#
#         marker_542e27931b297ac8b2222a9340143a93.bindPopup(popup_51cc48b99c5aca53dad6bbe89f286c70)
#         ;
#
#
#
#
#             var marker_988003bc270e502fbc1dc765195cbfac = L.marker(
#                 [35.8867, 139.47],
#                 {&quot;maxHeight&quot;: 200}
#             ).addTo(map_c4d73ce6c1fc9154adaea9e6edc4222a);
#
#
#         var custom_icon_6a82bc9f87d92b9e61b634d4d0a24767 = L.icon({&quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [130, 25], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;, &quot;popupAnchor&quot;: [3, 3], &quot;shadowAnchor&quot;: [-4, -40]
# 2023-07-05 23:05:15,346| ERROR   | Socket exception: 既存の接続はリモート ホストに強制的に切断されました。 (10054)
# 2023-07-05 23:05:15,349| ERROR   | Socket exception: 既存の接続はリモート ホストに強制的に切断されました。 (10054)
# 2023-07-05 23:05:15,406| ERROR   | Socket exception: 既存の接続はリモート ホストに強制的に切断されました。 (10054)
# 2023-07-05 23:05:15,518| ERROR   | Socket exception: 既存の接続はリモート ホストに強制的に切断されました。 (10054)
# 2023-07-05 23:05:16,000| ERROR   | Socket exception: 既存の接続はリモート ホストに強制的に切断されました。 (10054)
# 2023-07-05 23:05:17,172| ERROR   | Socket exception: 既存の接続はリモート ホストに強制的に切断されました。 (10054)
# 2023-07-05 23:05:17,175| ERROR   | Socket exception: 既存の接続はリモート ホストに強制的に切断されました。 (10054)
# 2023-07-05 23:05:17,390| ERROR   | Socket exception: 既存の接続はリモート ホストに強制的に切断されました。 (10054)
# 2023-07-05 23:05:17,612| ERROR   | Socket exception: 既存の接続はリモート ホストに強制的に切断されました。 (10054)

# %% [markdown]
# ### MAPを使ったTwitter画像表示用

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import datetime
import time
import unicodedata
import string
import requests
from PIL import Image, ImageDraw, ImageFont
import folium
from folium.features import CustomIcon
# 地図生成
folium_map = folium.Map(location=[35.6894 ,139.6917], zoom_start=11)
# 地図表示
# マーカープロット（ポップアップ設定，色変更，アイコン変更）
for i, record in report_df.iterrows():
    #print(record['店舗名'])
    
    # グレースケールの画像データを作成
    img = Image.new("L", (100, 100),color=(55))
    im = img.copy()
    # 画像の表示
    im.putalpha(100)
    # 描画準備
    draw = ImageDraw.Draw(im)
    font = ImageFont.truetype('font\LightNovelPOPv2.otf',10)
    syuzai_name_text = ''
    extract_syuzai_df_1 = report_df[report_df['店舗名'] == record['店舗名']]
    extract_syuzai_df_2 = extract_syuzai_df_1.drop_duplicates(keep='first')
    for i,syuzai_record in extract_syuzai_df_2.iterrows():
        #print(record)
        syuzai_name_text += '◆' + syuzai_record['媒体名'] + '\n' + syuzai_record['取材名'] + '\n'
    #print(syuzai_name_text)
    draw.multiline_text(
        (50, 0),
        f'{record["店舗名"]}\n{syuzai_name_text}',
        font=font,
        fill='white',
        align='center',
        anchor='ma'
    )
    # 画像を表示
    im.save('syuzai_image.png', quality=95)
    img = 'syuzai_image.png'
    try:
        folium.Marker(location=[record['緯度'] ,record['経度']],
        popup=record['店舗名'],
        icon = CustomIcon(
                    icon_image = img,
                    icon_size = (70, 70),
                    icon_anchor = (0, 0),
                    #shadow_image = shadow_img, # 影効果（今回は使用せず コメントアウト
                    #shadow_size = (30, 30),
                    #shadow_anchor = (-4, -40),
                    popup_anchor = (3, 3))).add_to(folium_map)
    except:
        continue
        #break
folium_map.save(outfile="./test_map.html")
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5f4ff3a0be13c8c8f3e23209e2b7c18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5f4ff3a0be13c8c8f3e23209e2b7c18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5f4ff3a0be13c8c8f3e23209e2b7c18 = L.map(
#                 &quot;map_b5f4ff3a0be13c8c8f3e23209e2b7c18&quot;,
#                 {
#                     center: [35.6894, 139.6917],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ba28893d723b5703752d855fd465eb8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b5f4ff3a0be13c8c8f3e23209e2b7c18);
#
#
#             var marker_9641e2ec68f7a00c11b00980765b9135 = L.marker(
#                 [35.8867, 139.47],
#                 {}
#             ).addTo(map_b5f4ff3a0be13c8c8f3e23209e2b7c18);
#
#
#             var icon_8c9773aa051d7739674aa666227d3350 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9641e2ec68f7a00c11b00980765b9135.setIcon(icon_8c9773aa051d7739674aa666227d3350);
#
#
#         var popup_ef2d14c65d8dc91cce25ebca59eac651 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4595c3cd8aba226cfcf4eea932e7418 = $(`&lt;div id=&quot;html_f4595c3cd8aba226cfcf4eea932e7418&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;マルハン川越店&lt;/div&gt;`)[0];
#                 popup_ef2d14c65d8dc91cce25ebca59eac651.setContent(html_f4595c3cd8aba226cfcf4eea932e7418);
#
#
#
#         marker_9641e2ec68f7a00c11b00980765b9135.bindPopup(popup_ef2d14c65d8dc91cce25ebca59eac651)
#         ;
#
#
#
#
#             var marker_97f12d9a27025fd3edbe84eb28d10a14 = L.marker(
#                 [35.8391, 139.551],
#                 {}
#             ).addTo(map_b5f4ff3a0be13c8c8f3e23209e2b7c18);
#
#
#             var icon_e7f456d3ec37cd999dfcce2bfe38d494 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_97f12d9a27025fd3edbe84eb28d10a14.setIcon(icon_e7f456d3ec37cd999dfcce2bfe38d494);
#
#
#         var popup_f537d20b3411311fc5438b3cca119197 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf69773c7362457f3c35cb6c82d031ed = $(`&lt;div id=&quot;html_bf69773c7362457f3c35cb6c82d031ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;第一プラザみずほ台店&lt;/div&gt;`)[0];
#                 popup_f537d20b3411311fc5438b3cca119197.setContent(html_bf69773c7362457f3c35cb6c82d031ed);
#
#
#
#         marker_97f12d9a27025fd3edbe84eb28d10a14.bindPopup(popup_f537d20b3411311fc5438b3cca119197)
#         ;
#
#
#
#
#             var marker_cf61ad0411b6a431272d6e58c0c5b098 = L.marker(
#                 [35.9159, 139.484],
#                 {}
#             ).addTo(map_b5f4ff3a0be13c8c8f3e23209e2b7c18);
#
#
#             var icon_312f3e2c7c96f9c3391d304f541d3709 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cf61ad0411b6a431272d6e58c0c5b098.setIcon(icon_312f3e2c7c96f9c3391d304f541d3709);
#
#
#         var popup_bbd3d385dfd0a0009c7459aa15356f63 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b4534381bf4097cf008fd478f48ab6c0 = $(`&lt;div id=&quot;html_b4534381bf4097cf008fd478f48ab6c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;パラッツォ川越店&lt;/div&gt;`)[0];
#                 popup_bbd3d385dfd0a0009c7459aa15356f63.setContent(html_b4534381bf4097cf008fd478f48ab6c0);
#
#
#
#         marker_cf61ad0411b6a431272d6e58c0c5b098.bindPopup(popup_bbd3d385dfd0a0009c7459aa15356f63)
#         ;
#
#
#
#
#             var marker_3b6941168d4b07683056456603211eec = L.marker(
#                 [35.9159, 139.484],
#                 {}
#             ).addTo(map_b5f4ff3a0be13c8c8f3e23209e2b7c18);
#
#
#             var icon_ce3625e7d88871e03f349ef95e21b101 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconCol

# %% [markdown]
# ### 重複取材をSQLで数え上げる

# %%
cursor, cnx, server = get_driver()
sql = f"""SELECT *
FROM schedule
GROUP BY 店舗名,イベント日,取材名
HAVING COUNT(*) >= 2
ORDER BY イベント日 DESC
LIMIT 20;
        """
print(sql)
cursor.execute(sql)
cols = [col[0] for col in cursor.description]
df =  pd.DataFrame(cursor.fetchall(),columns = cols )
df
# Out:
# 2023-07-04 01:04:05.972756
# local bind port: 56803
# sql connection status: True
# SELECT *
# FROM schedule
# GROUP BY 店舗名,イベント日,取材名
# HAVING COUNT(*) >= 2
# ORDER BY イベント日 DESC
# LIMIT 20;
#        id  都道府県       イベント日 曜日                店舗名                取材名
# 0   64026   千葉県  2023-07-09  日  パチンコウエスタン浦安やなぎ通り店             頂チャンネル  \
# 1   63566   埼玉県  2023-07-09  日            ガーデン北戸田                おゆん
# 2   63405   埼玉県  2023-07-09  日        新！ガーデン川口安行店             あしゅら広告
# 3   63268  神奈川県  2023-07-09  日          パラッツォ湘南台店  スコーピオン取材 結束の刻(真紅)
# 4   63301   千葉県  2023-07-09  日          エクス・アリーナ柏            昇天チャレンジ
# 5   64027   千葉県  2023-07-09  日         ウエスタン浦安駅前店             頂チャンネル
# 6   63567  神奈川県  2023-07-09  日           キコーナ茅ヶ崎店                万太郎
# 7   63406  神奈川県  2023-07-09  日          ピーアーク相模大野             あしゅら広告
# 8   63269   埼玉県  2023-07-09  日            アリーナ平塚店  スコーピオン取材 結束の刻(真紅)
# 9   63302   東京都  2023-07-09  日        ピーアーク北千住SSS            昇天チャレンジ
# 10  63335   埼玉県  2023-07-09  日         新！ガーデン北与野店    でちゃう編集部来店(鈴木優梨)
# 11  63174   埼玉県  2023-07-09  日             キコーナ草加    1GAMEホール取材 むつかけ
# 12  63407   栃木県  2023-07-09  日         マルハン小山千駄塚店             あしゅら広告
# 13  63270   埼玉県  2023-07-09  日             ガーデン川越     降臨シリーズ トールハンマー
# 14  63303  神奈川県  2023-07-09  日    アビバANNEX&SQUARE            昇天チャレンジ
# 15  63304  神奈川県  2023-07-09  日          アビバ横須賀中央店            昇天チャレンジ
# 16  63408  神奈川県  2023-07-09  日            クリエ湘南台店             りゅーこ広告
# 17  63271   埼玉県  2023-07-09  日          新！ガーデン桶川店  スコーピオン取材 結束の極(真紅)
# 18  63409  神奈川県  2023-07-09  日             アビバ鶴見店          ぎょくあしゅら広告
# 19  63441  神奈川県  2023-07-09  日         キコーナ小田原扇町店              アツ姫来店
#
#            媒体名 取材ランク       取得時間
# 0   頂-ITADAKI-     B 2023-07-03
# 1         グーパチ     A 2023-07-03
# 2         りゅーこ     C 2023-07-03
# 3     DMMぱちタウン     A 2023-07-03
# 4        えいりヤン     C 2023-07-03
# 5   頂-ITADAKI-     B 2023-07-03
# 6         グーパチ     B 2023-07-03
# 7         りゅーこ     C 2023-07-03
# 8     DMMぱちタウン     A 2023-07-03
# 9        えいりヤン     C 2023-07-03
# 10       でちゃう！     B 2023-07-03
# 11       1game     ・ 2023-07-03
# 12        りゅーこ     C 2023-07-03
# 13    DMMぱちタウン     A 2023-07-03
# 14       えいりヤン     C 2023-07-03
# 15       えいりヤン     C 2023-07-03
# 16        りゅーこ     ・ 2023-07-03
# 17    DMMぱちタウン     B 2023-07-03
# 18        りゅーこ     ・ 2023-07-03
# 19         アツ姫     B 2023-07-03
